# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
plt.subplot(2,2, 1)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()
plt.subplot(2,2,1)
plt.plot(x, x, 'b--')
plt.plot(x, 2*x, 'r-')
plt.show()
